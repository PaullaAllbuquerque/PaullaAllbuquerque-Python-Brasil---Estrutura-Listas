# %%
'''Exercício 21 - Faça um programa que carregue uma lista com os modelos de cinco carros 
(exemplo de modelos: FUSCA, GOL, VECTRA etc). Carregue uma outra lista com o consumo desses carros, isto é, 
quantos quilômetros cada um desses carros faz com um litro de combustível. Calcule e mostre:
O modelo do carro mais econômico;
Quantos litros de combustível cada um dos carros cadastrados consome 
para percorrer uma distância de 1000 quilômetros e quanto isto custará, 
considerando um que a gasolina custe R$ 2,25 o litro. Abaixo segue uma tela de exemplo. 
O disposição das informações deve ser o mais próxima possível ao exemplo. Os dados são fictícios e podem mudar 
a cada execução do programa.
Comparativo de Consumo de Combustível

Veículo 1
Nome: fusca
Km por litro: 7
Veículo 2
Nome: gol
Km por litro: 10
Veículo 3
Nome: uno
Km por litro: 12.5
Veículo 4
Nome: Vectra
Km por litro: 9
Veículo 5
Nome: Peugeout
Km por litro: 14.5

Relatório Final
 1 - fusca           -    7.0 -  142.9 litros - R$ 321.43
 2 - gol             -   10.0 -  100.0 litros - R$ 225.00
 3 - uno             -   12.5 -   80.0 litros - R$ 180.00
 4 - vectra          -    9.0 -  111.1 litros - R$ 250.00
 5 - peugeout        -   14.5 -   69.0 litros - R$ 155.17
O menor consumo é do peugeout.'''

modelos=[]
consumo=[]
preco=[]

for carro in range(1,6):
    print(f'\n VEÍCULO {carro}')
    model=str(input(f'Modelo:'))
    modelos.append(model)
    cons=float(input(f'Km por litro:'))
    consumo.append(cons)
print('\n')
print('RELATÓRIO FINAL')
print('='*20)


for m in range(0,len(modelos)):
    litros=1000/consumo[m]
    prec=litros*2.25
    print(f'{m+1} - {modelos[m]:<7} - {consumo[m]:>6} - {round(litros):>5.1f} - R${round(prec):.2f}')
    preco.append(prec)
    
menorConsumo=consumo.index(max(consumo))
print(f'O menor consumo é o do {modelos[menorConsumo]}')
# Out:
#  VEÍCULO 1
# Modelo:Fusca
# Km por litro:7
#
#  VEÍCULO 2
# Modelo:Gol
# Km por litro:10
#
#  VEÍCULO 3
# Modelo:Uno
# Km por litro:12.5
#
#  VEÍCULO 4
# Modelo:Vectra
# Km por litro:9
#
#  VEÍCULO 5
# Modelo:Peugeot
# Km por litro:14.5
#
#
# RELATÓRIO FINAL
# ...
# 1 - Fusca   -    7.0 - 143.0 - R$321.00
# 2 - Gol     -   10.0 - 100.0 - R$225.00
# 3 - Uno     -   12.5 -  80.0 - R$180.00
# 4 - Vectra  -    9.0 - 111.0 - R$250.00
# 5 - Peugeot -   14.5 -  69.0 - R$155.00
# O menor consumo é o do Peugeot

# %%
'''Exercício 22 - Sua organização acaba de contratar um estagiário para trabalhar no Suporte de Informática, 
com a intenção de fazer um levantamento nas sucatas encontradas nesta área. A primeira tarefa dele é testar todos os 
cerca de 200 mouses que se encontram lá, testando e anotando o estado de cada um deles, para verificar o que se pode
aproveitar deles.
Foi requisitado que você desenvolva um programa para registrar este levantamento. O programa deverá receber um número
indeterminado de entradas, cada uma contendo: um número de identificação do mouse o tipo de defeito:
necessita da esfera;
necessita de limpeza; a.necessita troca do cabo ou conector; a.quebrado ou inutilizado Uma identificação
igual a zero encerra o programa. Ao final o programa deverá emitir o seguinte relatório:
Quantidade de mouses: 100

Situação                        Quantidade              Percentual
1- necessita da esfera                  40                     40%
2- necessita de limpeza                 30                     30%
3- necessita troca do cabo ou conector  15                     15%
4- quebrado ou inutilizado              15                     15%'''

defeito=['Necessita da esfera', 'Necessita de limpeza', 'Necessita troca do cabo ou conector', 'Quebrado ou inutilizado']
codId=True
nIdentificacao=[]
nDefeito=[]
mouse=1

while codId != 0:
    codId=int(input('Número Identifiador: '))
    if codId==0:
        break
    else:
        while codId in nIdentificacao:
            print('[NÚMERO REPETIDO]')
            codId=int(input('Número Identifiador: '))
        defe=int(input('Insira o código do defeito:'))
        while defe < 1 or defe > 4:
            print('[NÚMERO INVÁLIDO]')
            defe=int(input('Insira o código do defeito:'))
        nIdentificacao.append(codId)
        nDefeito.append(defe)
    mouse+=1
    
print(f'\nQUANTIDADE DE MOUSES: {len(nIdentificacao)}')
print('\n{:<40}{:>7}{:>15}'.format('SITUAÇÃO', 'QUANTIDADE', 'PERCENTUAL'))
print('{:<40}{:>7}{:>15}'.format('-'*30, '-'*12, '-'*12))
for d in range(0,len(defeito)):
    porcento= (nDefeito.count(d+1)*100)/len(nIdentificacao)
    print('{:<40}{:>7}{:>15}'.format(defeito[d],nDefeito.count(d+1),round(porcento,2)),'%')
# Out:
# Número Identifiador: 1
# Insira o código do defeito:4
# Número Identifiador: 2
# Insira o código do defeito:4
# Número Identifiador: 3
# Insira o código do defeito:1
# Número Identifiador: 4
# Insira o código do defeito:2
# Número Identifiador: 0
#
# QUANTIDADE DE MOUSES: 4
#
# SITUAÇÃO                                QUANTIDADE     PERCENTUAL
# ------------------------------          ------------   ------------
# Necessita da esfera                           1           25.0 %
# Necessita de limpeza                          1           25.0 %
# Necessita troca do cabo ou conector           0            0.0 %
# Quebrado ou inutilizado                       2           50.0 %

# %%
'''Exercício 23 - A ACME Inc., uma empresa de 500 funcionários, está tendo problemas de espaço em disco no seu servidor 
de arquivos. Para tentar resolver este problema, o Administrador de Rede precisa saber qual o espaço ocupado pelos usuários, 
e identificar os usuários com maior espaço ocupado. Através de um programa, baixado da Internet, 
ele conseguiu gerar o seguinte arquivo, chamado "usuarios.txt":
alexandre       456123789
anderson        1245698456
antonio         123456456
carlos          91257581
cesar           987458
rosemary        789456125
Neste arquivo, o nome do usuário possui 15 caracteres. A partir deste arquivo, você deve criar um 
programa que gere um relatório, chamado "relatório.txt", no seguinte formato:
ACME Inc.               Uso do espaço em disco pelos usuários
------------------------------------------------------------------------
Nr.  Usuário        Espaço utilizado     % do uso

1    alexandre       434,99 MB             16,85%
2    anderson       1187,99 MB             46,02%
3    antonio         117,73 MB              4,56%
4    carlos           87,03 MB              3,37%
5    cesar             0,94 MB              0,04%
6    rosemary        752,88 MB             29,16%

Espaço total ocupado: 2581,57 MB
Espaço médio ocupado: 430,26 MB'''

nomes=['Alexandre','Anderson','Antonio','Carlos','Cesar','Rosemary']
espaco=[456123789, 1245698456, 123456456, 91257581, 987458, 789456125]

print('{:<10}{:>60}'.format('ACME Inc.','Uso do Espaço em disco pelos usuários'))
print('='*80)
print('{:<4}{:>7}{:>20}{:>13}'.format('Nr', 'Usuário', 'Espaço utilizado', '% do uso'))
print('{:<4}{:>7}{:>20}{:>13}'.format('-'*3, '-'*8, '-'*18, '-'*10))

for pos in range(0,len(espaco)):
    conversao= espaco[pos]/1000000
    porcento=(espaco[pos]*100)/sum(espaco)
    print('{:<4}{:>10}{:>10.2f} MB{:>20.2f}%'.format(pos,nomes[pos],(round(conversao)),round(porcento)))

print('\n{}{:.2f} MB'.format('Espaço total ocupado:', (sum(espaco)/1000000)))
print('{}{:.2f} MB'.format('Espaço médio ocupado:', (sum(espaco)/len(espaco)/1000000)))
# Out:
# ACME Inc.                        Uso do Espaço em disco pelos usuários
# ...
# Nr  Usuário    Espaço utilizado     % do uso
# --- --------  ------------------   ----------
# 0    Alexandre    456.00 MB               17.00%
# 1     Anderson   1246.00 MB               46.00%
# 2      Antonio    123.00 MB                5.00%
# 3       Carlos     91.00 MB                3.00%
# 4        Cesar      1.00 MB                0.00%
# 5     Rosemary    789.00 MB               29.00%
#
# Espaço total ocupado:2706.98 MB
# Espaço médio ocupado:451.16 MB

# %%
'''Exercício 24 - Faça um programa que simule um lançamento de dados. Lance o dado 100 vezes e
armazene os resultados em um vetor . Depois, mostre quantas vezes cada valor foi conseguido. 
Dica: use um vetor de contadores(1-6) e uma função para gerar numeros aleatórios, simulando os lançamentos dos dados.
'''

import random
lancamento=[]
for l in range(100):
    lancamento.append(random.randrange(1,6+1))
for l in range(6):
    print('O número', l+1, 'foi gerado', lancamento.count(l+1), 'vezes')
# Out:
# O número 1 foi gerado 17 vezes
# O número 2 foi gerado 16 vezes
# O número 3 foi gerado 18 vezes
# O número 4 foi gerado 18 vezes
# O número 5 foi gerado 14 vezes
# O número 6 foi gerado 17 vezes
